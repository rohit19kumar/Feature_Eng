# %% [markdown]
# <a href="https://colab.research.google.com/github/rohit19kumar/CiQ/blob/master/FMNIST_GAN.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import torch
import matplotlib.pyplot as plt

# %%
from torchvision import datasets
import torchvision.transforms as transforms

# number of subprocesses to use for data loading
num_workers = 0
# how many samples per batch to load
batch_size = 64

# convert data to torch.FloatTensor
transform = transforms.ToTensor()

# get the training datasets
train_data = datasets.FashionMNIST(root='data', train=True,
                                   download=True, transform=transform)

# prepare data loader
train_loader = torch.utils.data.DataLoader(train_data, batch_size=batch_size,
                                           num_workers=num_workers)
# Out:
# 0it [00:00, ?it/s]
# Downloading http://fashion-mnist.s3-website.eu-central-1.amazonaws.com/train-images-idx3-ubyte.gz to data/FashionMNIST/raw/train-images-idx3-ubyte.gz
# 26427392it [00:01, 13326236.39it/s]
# Extracting data/FashionMNIST/raw/train-images-idx3-ubyte.gz
# 0it [00:00, ?it/s]
# Downloading http://fashion-mnist.s3-website.eu-central-1.amazonaws.com/train-labels-idx1-ubyte.gz to data/FashionMNIST/raw/train-labels-idx1-ubyte.gz
# 32768it [00:00, 95427.68it/s]
# 0it [00:00, ?it/s]
# Extracting data/FashionMNIST/raw/train-labels-idx1-ubyte.gz
# Downloading http://fashion-mnist.s3-website.eu-central-1.amazonaws.com/t10k-images-idx3-ubyte.gz to data/FashionMNIST/raw/t10k-images-idx3-ubyte.gz
# 4423680it [00:01, 3900347.80it/s]
# 0it [00:00, ?it/s]
# Extracting data/FashionMNIST/raw/t10k-images-idx3-ubyte.gz
# Downloading http://fashion-mnist.s3-website.eu-central-1.amazonaws.com/t10k-labels-idx1-ubyte.gz to data/FashionMNIST/raw/t10k-labels-idx1-ubyte.gz
# 8192it [00:00, 32658.21it/s]
# Extracting data/FashionMNIST/raw/t10k-labels-idx1-ubyte.gz
# Processing...
# Done!

# %%
# obtain one batch of training images
dataiter = iter(train_loader)
images, labels = dataiter.next()
images = images.numpy()

# get one image from the batch
img = np.squeeze(images[0])

fig = plt.figure(figsize = (3,3)) 
ax = fig.add_subplot(111)
ax.imshow(img , cmap='gray')

# %%
import torch.nn as nn
import torch.nn.functional as F

class Discriminator(nn.Module):

    def __init__(self, input_size, hidden_dim, output_size):
        super(Discriminator, self).__init__()
        
        # define hidden linear layers
        self.fc1 = nn.Linear(input_size, hidden_dim*4)
        self.fc2 = nn.Linear(hidden_dim*4, hidden_dim*2)
        self.fc3 = nn.Linear(hidden_dim*2, hidden_dim)
        
        # final fully-connected layer
        self.fc4 = nn.Linear(hidden_dim, output_size)
        
        # dropout layer 
        self.dropout = nn.Dropout(0.3)
        
        
    def forward(self, x):
        # flatten image
        x = x.view(-1, 28*28)
        # all hidden layers
        x = F.leaky_relu(self.fc1(x), 0.2) # (input, negative_slope=0.2)
        x = self.dropout(x)
        x = F.leaky_relu(self.fc2(x), 0.2)
        x = self.dropout(x)
        x = F.leaky_relu(self.fc3(x), 0.2)
        x = self.dropout(x)
        # final layer
        out = self.fc4(x)

        return out

# %%
class Generator(nn.Module):

    def __init__(self, input_size, hidden_dim, output_size):
        super(Generator, self).__init__()
        
        # define hidden linear layers
        self.fc1 = nn.Linear(input_size, hidden_dim)
        self.fc2 = nn.Linear(hidden_dim, hidden_dim*2)
        self.fc3 = nn.Linear(hidden_dim*2, hidden_dim*4)
        
        # final fully-connected layer
        self.fc4 = nn.Linear(hidden_dim*4, output_size)
        
        # dropout layer 
        self.dropout = nn.Dropout(0.3)

    def forward(self, x):
        # all hidden layers
        x = F.leaky_relu(self.fc1(x), 0.2) # (input, negative_slope=0.2)
        x = self.dropout(x)
        x = F.leaky_relu(self.fc2(x), 0.2)
        x = self.dropout(x)
        x = F.leaky_relu(self.fc3(x), 0.2)
        x = self.dropout(x)
        # final layer with tanh applied
        out = torch.tanh(self.fc4(x))

        return out

# %%
# Discriminator hyperparams

# Size of input image to discriminator (28*28)
input_size = 784
# Size of discriminator output (real or fake)
d_output_size = 1
# Size of last hidden layer in the discriminator
d_hidden_size = 32

# Generator hyperparams

# Size of latent vector to give to generator
z_size = 100
# Size of discriminator output (generated image)
g_output_size = 784
# Size of first hidden layer in the generator
g_hidden_size = 32

# %%
# instantiate discriminator and generator
D = Discriminator(input_size, d_hidden_size, d_output_size)
G = Generator(z_size, g_hidden_size, g_output_size)

# check that they are as you expect
print(D)
print()
print(G)
# Out:
# Discriminator(
#   (fc1): Linear(in_features=784, out_features=128, bias=True)
#   (fc2): Linear(in_features=128, out_features=64, bias=True)
#   (fc3): Linear(in_features=64, out_features=32, bias=True)
#   (fc4): Linear(in_features=32, out_features=1, bias=True)
#   (dropout): Dropout(p=0.3)
# )
#
# Generator(
#   (fc1): Linear(in_features=100, out_features=32, bias=True)
#   (fc2): Linear(in_features=32, out_features=64, bias=True)
#   (fc3): Linear(in_features=64, out_features=128, bias=True)
#   (fc4): Linear(in_features=128, out_features=784, bias=True)
#   (dropout): Dropout(p=0.3)
# )

# %%
# Calculate losses
def real_loss(D_out, smooth=False):
    batch_size = D_out.size(0)
    # label smoothing
    if smooth:
        # smooth, real labels = 0.9
        labels = torch.ones(batch_size)*0.9
    else:
        labels = torch.ones(batch_size) # real labels = 1
        
    # numerically stable loss
    criterion = nn.BCEWithLogitsLoss()
    # calculate loss
    loss = criterion(D_out.squeeze(), labels)
    return loss

def fake_loss(D_out):
    batch_size = D_out.size(0)
    labels = torch.zeros(batch_size) # fake labels = 0
    criterion = nn.BCEWithLogitsLoss()
    # calculate loss
    loss = criterion(D_out.squeeze(), labels)
    return loss

# %%
import torch.optim as optim

# Optimizers
lr = 0.002

# Create optimizers for the discriminator and generator
d_optimizer = optim.Adam(D.parameters(), lr)
g_optimizer = optim.Adam(G.parameters(), lr)

# %%
import pickle as pkl

# training hyperparams
num_epochs = 100

# keep track of loss and generated, "fake" samples
samples = []
losses = []

print_every = 400

# Get some fixed data for sampling. These are images that are held
# constant throughout training, and allow us to inspect the model's performance
sample_size=16
fixed_z = np.random.uniform(-1, 1, size=(sample_size, z_size))
fixed_z = torch.from_numpy(fixed_z).float()

# train the network
D.train()
G.train()
for epoch in range(num_epochs):
    
    for batch_i, (real_images, _) in enumerate(train_loader):
                
        batch_size = real_images.size(0)
        
        ## Important rescaling step ## 
        real_images = real_images*2 - 1  # rescale input images from [0,1) to [-1, 1)
        
        # ============================================
        #            TRAIN THE DISCRIMINATOR
        # ============================================
        
        d_optimizer.zero_grad()
        
        # 1. Train with real images

        # Compute the discriminator losses on real images 
        # smooth the real labels
        D_real = D(real_images)
        d_real_loss = real_loss(D_real, smooth=True)
        
        # 2. Train with fake images
        
        # Generate fake images
        z = np.random.uniform(-1, 1, size=(batch_size, z_size))
        z = torch.from_numpy(z).float()
        fake_images = G(z)
        
        # Compute the discriminator losses on fake images        
        D_fake = D(fake_images)
        d_fake_loss = fake_loss(D_fake)
        
        # add up loss and perform backprop
        d_loss = d_real_loss + d_fake_loss
        d_loss.backward()
        d_optimizer.step()
        
        #            TRAIN THE GENERATOR
        # =========================================
        g_optimizer.zero_grad()
        
        # 1. Train with fake images and flipped labels
        
        # Generate fake images
        z = np.random.uniform(-1, 1, size=(batch_size, z_size))
        z = torch.from_numpy(z).float()
        fake_images = G(z)
        
        # Compute the discriminator losses on fake images 
        # using flipped labels!
        D_fake = D(fake_images)
        g_loss = real_loss(D_fake) # use real loss to flip labels
        
        # perform backprop
        g_loss.backward()
        g_optimizer.step()

        # Print some loss stats
        if batch_i % print_every == 0:
            # print discriminator and generator loss
            print('Epoch [{:5d}/{:5d}] | d_loss: {:6.4f} | g_loss: {:6.4f}'.format(
                    epoch+1, num_epochs, d_loss.item(), g_loss.item()))

            
   ## AFTER EACH EPOCH##
    # append discriminator loss and generator loss
    losses.append((d_loss.item(), g_loss.item()))
    
    # generate and save sample, fake images
    G.eval() # eval mode for generating samples
    samples_z = G(fixed_z)
    samples.append(samples_z)
    G.train() # back to train mode


# Save training generator samples
with open('train_samples.pkl', 'wb') as f:
    pkl.dump(samples, f)
# Out:
# Epoch [    1/  100] | d_loss: 0.9014 | g_loss: 2.0516
# Epoch [    1/  100] | d_loss: 1.0587 | g_loss: 1.8341
# Epoch [    1/  100] | d_loss: 1.0744 | g_loss: 1.8556
# Epoch [    2/  100] | d_loss: 1.2214 | g_loss: 1.4024
# Epoch [    2/  100] | d_loss: 1.2714 | g_loss: 1.3534
# Epoch [    2/  100] | d_loss: 1.0165 | g_loss: 1.7033
# Epoch [    3/  100] | d_loss: 1.1943 | g_loss: 1.2731
# Epoch [    3/  100] | d_loss: 1.2042 | g_loss: 1.4141
# Epoch [    3/  100] | d_loss: 1.1997 | g_loss: 1.3571
# Epoch [    4/  100] | d_loss: 1.1049 | g_loss: 1.3913
# Epoch [    4/  100] | d_loss: 0.9803 | g_loss: 2.4252
# Epoch [    4/  100] | d_loss: 1.3583 | g_loss: 1.8040
# Epoch [    5/  100] | d_loss: 1.2035 | g_loss: 1.5792
# Epoch [    5/  100] | d_loss: 1.1162 | g_loss: 1.4419
# Epoch [    5/  100] | d_loss: 1.2796 | g_loss: 1.2715
# Epoch [    6/  100] | d_loss: 1.2243 | g_loss: 1.2392
# Epoch [    6/  100] | d_loss: 1.2164 | g_loss: 1.4992
# Epoch [    6/  100] | d_loss: 1.1705 | g_loss: 1.4701
# Epoch [    7/  100] | d_loss: 1.3478 | g_loss: 0.7966
# Epoch [    7/  100] | d_loss: 1.2278 | g_loss: 1.0852
# Epoch [    7/  100] | d_loss: 1.1383 | g_loss: 1.2108
# Epoch [    8/  100] | d_loss: 1.2364 | g_loss: 1.0783
# Epoch [    8/  100] | d_loss: 1.2703 | g_loss: 1.3206
# Epoch [    8/  100] | d_loss: 1.2171 | g_loss: 1.1271
# Epoch [    9/  100] | d_loss: 1.1336 | g_loss: 1.2144
# Epoch [    9/  100] | d_loss: 1.0648 | g_loss: 1.2164
# Epoch [    9/  100] | d_loss: 1.3081 | g_loss: 1.6153
# Epoch [   10/  100] | d_loss: 1.5254 | g_loss: 1.3104
# Epoch [   10/  100] | d_loss: 1.1122 | g_loss: 1.5001
# Epoch [   10/  100] | d_loss: 1.2309 | g_loss: 1.3825
# Epoch [   11/  100] | d_loss: 1.2577 | g_loss: 1.4124
# Epoch [   11/  100] | d_loss: 1.1725 | g_loss: 1.0986
# Epoch [   11/  100] | d_loss: 1.2028 | g_loss: 1.2730
# Epoch [   12/  100] | d_loss: 1.1774 | g_loss: 1.5941
# Epoch [   12/  100] | d_loss: 1.2217 | g_loss: 1.2128
# Epoch [   12/  100] | d_loss: 1.3694 | g_loss: 1.5695
# Epoch [   13/  100] | d_loss: 1.3020 | g_loss: 1.1170
# Epoch [   13/  100] | d_loss: 1.3726 | g_loss: 1.1700
# Epoch [   13/  100] | d_loss: 1.2664 | g_loss: 1.1115
# Epoch [   14/  100] | d_loss: 1.2822 | g_loss: 1.8686
# Epoch [   14/  100] | d_loss: 1.3245 | g_loss: 1.3943
# Epoch [   14/  100] | d_loss: 1.3006 | g_loss: 1.0946
# Epoch [   15/  100] | d_loss: 1.2944 | g_loss: 1.5046
# Epoch [   15/  100] | d_loss: 1.3386 | g_loss: 1.1940
# Epoch [   15/  100] | d_loss: 1.2687 | g_loss: 1.0893
# Epoch [   16/  100] | d_loss: 1.3014 | g_loss: 0.9868
# Epoch [   16/  100] | d_loss: 1.1316 | g_loss: 1.4272
# Epoch [   16/  100] | d_loss: 1.2773 | g_loss: 0.9287
# Epoch [   17/  100] | d_loss: 1.3117 | g_loss: 1.1610
# Epoch [   17/  100] | d_loss: 1.3103 | g_loss: 0.9659
# Epoch [   17/  100] | d_loss: 1.2620 | g_loss: 0.9980
# Epoch [   18/  100] | d_loss: 1.2724 | g_loss: 1.1059
# Epoch [   18/  100] | d_loss: 1.2032 | g_loss: 1.5886
# Epoch [   18/  100] | d_loss: 1.3050 | g_loss: 1.1182
# Epoch [   19/  100] | d_loss: 1.1716 | g_loss: 1.7876
# Epoch [   19/  100] | d_loss: 1.2088 | g_loss: 1.2300
# Epoch [   19/  100] | d_loss: 1.1996 | g_loss: 1.2302
# Epoch [   20/  100] | d_loss: 1.2906 | g_loss: 1.2012
# Epoch [   20/  100] | d_loss: 1.4944 | g_loss: 1.0580
# Epoch [   20/  100] | d_loss: 1.2057 | g_loss: 1.2857
# Epoch [   21/  100] | d_loss: 1.2877 | g_loss: 1.0589
# Epoch [   21/  100] | d_loss: 1.3097 | g_loss: 1.1633
# Epoch [   21/  100] | d_loss: 1.3999 | g_loss: 1.0648
# Epoch [   22/  100] | d_loss: 1.2245 | g_loss: 1.1067
# Epoch [   22/  100] | d_loss: 1.2298 | g_loss: 1.1666
# Epoch [   22/  100] | d_loss: 1.1608 | g_loss: 1.5052
# Epoch [   23/  100] | d_loss: 1.3020 | g_loss: 1.1335
# Epoch [   23/  100] | d_loss: 1.3927 | g_loss: 1.0298
# Epoch [   23/  100] | d_loss: 1.2485 | g_loss: 1.4371
# Epoch [   24/  100] | d_loss: 1.2515 | g_loss: 1.2293
# Epoch [   24/  100] | d_loss: 1.2916 | g_loss: 0.9416
# Epoch [   24/  100] | d_loss: 1.1170 | g_loss: 1.7043
# Epoch [   25/  100] | d_loss: 1.3134 | g_loss: 0.9250
# Epoch [   25/  100] | d_loss: 1.3628 | g_loss: 1.1459
# Epoch [   25/  100] | d_loss: 1.1315 | g_loss: 1.4459
# Epoch [   26/  100] | d_loss: 1.2085 | g_loss: 1.3986
# Epoch [   26/  100] | d_loss: 1.3113 | g_loss: 0.9777
# Epoch [   26/  100] | d_loss: 1.3178 | g_loss: 1.1030
# Epoch [   27/  100] | d_loss: 1.3664 | g_loss: 1.3475
# Epoch [   27/  100] | d_loss: 1.0700 | g_loss: 1.2505
# Epoch [   27/  100] | d_loss: 1.2201 | g_loss: 1.3131
# Epoch [   28/  100] | d_loss: 1.1918 | g_loss: 1.0264
# Epoch [   28/  100] | d_loss: 1.2396 | g_loss: 1.4725
# Epoch [   28/  100] | d_loss: 1.2577 | g_loss: 1.2609
# Epoch [   29/  100] | d_loss: 1.3674 | g_loss: 1.1478
# Epoch [   29/  100] | d_loss: 1.1669 | g_loss: 1.1843
# Epoch [   29/  100] | d_loss: 1.2442 | g_loss: 1.0684
# Epoch [   30/  100] | d_loss: 1.2455 | g_loss: 1.2389
# Epoch [   30/  100] | d_loss: 1.3033 | g_loss: 1.1950
# Epoch [   30/  100] | d_loss: 1.2301 | g_loss: 0.9669
# Epoch [   31/  100] | d_loss: 1.2744 | g_loss: 1.2389
# Epoch [   31/  100] | d_loss: 1.0787 | g_loss: 1.3955
# Epoch [   31/  100] | d_loss: 1.2695 | g_loss: 1.0223
# Epoch [   32/  100] | d_loss: 1.2573 | g_loss: 1.2941
# Epoch [   32/  100] | d_loss: 1.3280 | g_loss: 0.9668
# Epoch [   32/  100] | d_loss: 1.1912 | g_loss: 1.0951
# Epoch [   33/  100] | d_loss: 1.4015 | g_loss: 0.8504
# Epoch [   33/  100] | d_loss: 1.2436 | g_loss: 1.1992
# Epoch [   33/  100] | d_loss: 1.3192 | g_loss: 0.8942
# Epoch [   34/  100] | d_loss: 1.3300 | g_loss: 1.3236
# Epoch [   34/  100] | d_loss: 1.3327 | g_loss: 0.9973
# Epoch [   34/  100] | d_loss: 1.1732 | g_loss: 1.1884
# Epoch [   35/  100] | d_loss: 1.3473 | g_loss: 1.0216
# Epoch [   35/  100] | d_loss: 1.3038 | g_loss: 1.2406
# Epoch [   35/  100] | d_loss: 1.2481 | g_loss: 1.0987
# Epoch [   36/  100] | d_loss: 1.2608 | g_loss: 1.0925
# Epoch [   36/  100] | d_loss: 1.2424 | g_loss: 1.1994
# Epoch [   36/  100] | d_loss: 1.3468 | g_loss: 1.2216
# Epoch [   37/  100] | d_loss: 1.3756 | g_loss: 1.1607
# Epoch [   37/  100] | d_loss: 1.2224 | g_loss: 1.0371
# Epoch [   37/  100] | d_loss: 1.2501 | g_loss: 1.2176
# Epoch [   38/  100] | d_loss: 1.5249 | g_loss: 1.7268
# Epoch [   38/  100] | d_loss: 1.1799 | g_loss: 1.4349
# Epoch [   38/  100] | d_loss: 1.2695 | g_loss: 1.0344
# Epoch [   39/  100] | d_loss: 1.2127 | g_loss: 1.2921
# Epoch [   39/  100] | d_loss: 1.2545 | g_loss: 0.9561
# Epoch [   39/  100] | d_loss: 1.4086 | g_loss: 1.2319
# Epoch [   40/  100] | d_loss: 1.2399 | g_loss: 1.6640
# Epoch [   40/  100] | d_loss: 1.3166 | g_loss: 1.2056
# Epoch [   40/  100] | d_loss: 1.1131 | g_loss: 1.4263
# Epoch [   41/  100] | d_loss: 1.2306 | g_loss: 0.9648
# Epoch [   41/  100] | d_loss: 1.2445 | g_loss: 1.1203
# Epoch [   41/  100] | d_loss: 1.0673 | g_loss: 1.3083
# Epoch [   42/  100] | d_loss: 1.2910 | g_loss: 0.9702
# Epoch [   42/  100] | d_loss: 1.3083 | g_loss: 0.8643
# Epoch [   42/  100] | d_loss: 1.3328 | g_loss: 0.9168
# Epoch [   43/  100] | d_loss: 1.1847 | g_loss: 1.1447
# Epoch [   43/  100] | d_loss: 1.2843 | g_loss: 0.9384
# Epoch [   43/  100] | d_loss: 1.2414 | g_loss: 1.2187
# Epoch [   44/  100] | d_loss: 1.2720 | g_loss: 0.9742
# Epoch [   44/  100] | d_loss: 1.2766 | g_loss: 1.0435
# Epoch [   44/  100] | d_loss: 1.3451 | g_loss: 0.9824
# Epoch [   45/  100] | d_loss: 1.1160 | g_loss: 1.1651
# Epoch [   45/  100] | d_loss: 1.2094 | g_loss: 1.0014
# Epoch [   45/  100] | d_loss: 1.3448 | g_loss: 1.2553
# Epoch [   46/  100] | d_loss: 1.3511 | g_loss: 0.9693
# Epoch [   46/  100] | d_loss: 1.1656 | g_loss: 1.1125
# Epoch [   46/  100] | d_loss: 1.1850 | g_loss: 1.1418
# Epoch [   47/  100] | d_loss: 1.3196 | g_loss: 1.0607
# Epoch [   47/  100] | d_loss: 1.1861 | g_loss: 1.2647
# Epoch [   47/  100] | d_loss: 1.2602 | g_loss: 1.0730
# Epoch [   48/  100] | d_loss: 1.3741 | g_loss: 1.0740
# Epoch [   48/  100] | d_loss: 1.3534 | g_loss: 1.0301
# Epoch [   48/  100] | d_loss: 1.2807 | g_loss: 1.1892
# Epoch [   49/  100] | d_loss: 1.3339 | g_loss: 1.1117
# Epoch [   49/  100] | d_loss: 1.2376 | g_loss: 0.9929
# Epoch [   49/  100] | d_loss: 1.2071 | g_loss: 1.2702
# Epoch [   50/  100] | d_loss: 1.4573 | g_loss: 0.8413
# Epoch [   50/  100] | d_loss: 1.2540 | g_loss: 1.4326
# Epoch [   50/  100] | d_loss: 1.3235 | g_loss: 0.9690
# Epoch [   51/  100] | d_loss: 1.3046 | g_loss: 1.0511
# Epoch [   51/  100] | d_loss: 1.2747 | g_loss: 0.9438
# Epoch [   51/  100] | d_loss: 1.2413 | g_loss: 0.9494
# Epoch [   52/  100] | d_loss: 1.3256 | g_loss: 1.2361
# Epoch [   52/  100] | d_loss: 1.2766 | g_loss: 1.0494
# Epoch [   52/  100] | d_loss: 1.1894 | g_loss: 1.0183
# Epoch [   53/  100] | d_loss: 1.3121 | g_loss: 1.0234
# Epoch [   53/  100] | d_loss: 1.2531 | g_loss: 1.3242
# Epoch [   53/  100] | d_loss: 1.3325 | g_loss: 1.1004
# Epoch [   54/  100] | d_loss: 1.4316 | g_loss: 1.0165
# Epoch [   54/  100] | d_loss: 1.2995 | g_loss: 1.0310
# Epoch [   54/  100] | d_loss: 1.1871 | g_loss: 1.1595
# Epoch [   55/  100] | d_loss: 1.4560 | g_loss: 1.4784
# Epoch [   55/  100] | d_loss: 1.2352 | g_loss: 0.8812
# Epoch [   55/  100] | d_loss: 1.3056 | g_loss: 1.0899
# Epoch [   56/  100] | d_loss: 1.4048 | g_loss: 1.1525
# Epoch [   56/  100] | d_loss: 1.2744 | g_loss: 1.0572
# Epoch [   56/  100] | d_loss: 1.2605 | g_loss: 1.0402
# Epoch [   57/  100] | d_loss: 1.2221 | g_loss: 1.1910
# Epoch [   57/  100] | d_loss: 1.3186 | g_loss: 0.8338
# Epoch [   57/  100] | d_loss: 1.2594 | g_loss: 0.8816
# Epoch [   58/  100] | d_loss: 1.1813 | g_loss: 1.3023
# Epoch [   58/  100] | d_loss: 1.3749 | g_loss: 1.0530
# Epoch [   58/  100] | d_loss: 1.3067 | g_loss: 0.9671
# Epoch [   59/  100] | d_loss: 1.3206 | g_loss: 1.0073
# Epoch [   59/  100] | d_loss: 1.1801 | g_loss: 1.1763
# Epoch [   59/  100] | d_loss: 1.2130 | g_loss: 1.2745
# Epoch [   60/  100] | d_loss: 1.2997 | g_loss: 1.0363
# Epoch [   60/  100] | d_loss: 1.2940 | g_loss: 1.2132
# Epoch [   60/  100] | d_loss: 1.3887 | g_loss: 1.3286
# Epoch [   61/  100] | d_loss: 1.3253 | g_loss: 0.9979
# Epoch [   61/  100] | d_loss: 1.1871 | g_loss: 1.1529
# Epoch [   61/  100] | d_loss: 1.2685 | g_loss: 1.0415
# Epoch [   62/  100] | d_loss: 1.1604 | g_loss: 1.3989
# Epoch [   62/  100] | d_loss: 1.2470 | g_loss: 1.2139
# Epoch [   62/  100] | d_loss: 1.3264 | g_loss: 1.3299
# Epoch [   63/  100] | d_loss: 1.4059 | g_loss: 0.9734
# Epoch [   63/  100] | d_loss: 1.2752 | g_loss: 0.9532
# Epoch [   63/  100] | d_loss: 1.1863 | g_loss: 1.1761
# Epoch [   64/  100] | d_loss: 1.2714 | g_loss: 1.6035
# Epoch [   64/  100] | d_loss: 1.3692 | g_loss: 1.0342
# Epoch [   64/  100] | d_loss: 1.2352 | g_loss: 1.0707
# Epoch [   65/  100] | d_loss: 1.3477 | g_loss: 0.9806
# Epoch [   65/  100] | d_loss: 1.3454 | g_loss: 1.2186
# Epoch [   65/  100] | d_loss: 1.3289 | g_loss: 1.0088
# Epoch [   66/  100] | d_loss: 1.2736 | g_loss: 1.0983
# Epoch [   66/  100] | d_loss: 1.3767 | g_loss: 0.9268
# Epoch [   66/  100] | d_loss: 1.3280 | g_loss: 1.1610
# Epoch [   67/  100] | d_loss: 1.3406 | g_loss: 1.0766
# Epoch [   67/  100] | d_loss: 1.3106 | g_loss: 1.0348
# Epoch [   67/  100] | d_loss: 1.2537 | g_loss: 1.2274
# Epoch [   68/  100] | d_loss: 1.3203 | g_loss: 1.0884
# Epoch [   68/  100] | d_loss: 1.3500 | g_loss: 0.9708
# Epoch [   68/  100] | d_loss: 1.2674 | g_loss: 1.1965
# Epoch [   69/  100] | d_loss: 1.2466 | g_loss: 1.1042
# Epoch [   69/  100] | d_loss: 1.2747 | g_loss: 1.2550
# Epoch [   69/  100] | d_loss: 1.3143 | g_loss: 1.2062
# Epoch [   70/  100] | d_loss: 1.1897 | g_loss: 1.1432
# Epoch [   70/  100] | d_loss: 1.2422 | g_loss: 1.2360
# Epoch [   70/  100] | d_loss: 1.2769 | g_loss: 0.9068
# Epoch [   71/  100] | d_loss: 1.2936 | g_loss: 1.0057
# Epoch [   71/  100] | d_loss: 1.3260 | g_loss: 0.9652
# Epoch [   71/  100] | d_loss: 1.3105 | g_loss: 0.9285
# Epoch [   72/  100] | d_loss: 1.3249 | g_loss: 0.8787
# Epoch [   72/  100] | d_loss: 1.2492 | g_loss: 1.0780
# Epoch [   72/  100] | d_loss: 1.1950 | g_loss: 1.0795
# Epoch [   73/  100] | d_loss: 1.3297 | g_loss: 0.9913
# Epoch [   73/  100] | d_loss: 1.2547 | g_loss: 1.0471
# Epoch [   73/  100] | d_loss: 1.4523 | g_loss: 1.3254
# Epoch [   74/  100] | d_loss: 1.2601 | g_loss: 1.0905
# Epoch [   74/  100] | d_loss: 1.3364 | g_loss: 0.9105
# Epoch [   74/  100] | d_loss: 1.1975 | g_loss: 1.1456
# Epoch [   75/  100] | d_loss: 1.5051 | g_loss: 1.1132
# Epoch [   75/  100] | d_loss: 1.3139 | g_loss: 0.9834
# Epoch [   75/  100] | d_loss: 1.2717 | g_loss: 1.0820
# Epoch [   76/  100] | d_loss: 1.2426 | g_loss: 1.0568
# Epoch [   76/  100] | d_loss: 1.2202 | g_loss: 0.9973
# Epoch [   76/  100] | d_loss: 1.1995 | g_loss: 1.0820
# Epoch [   77/  100] | d_loss: 1.3245 | g_loss: 1.1385
# Epoch [   77/  100] | d_loss: 1.2855 | g_loss: 0.9295
# Epoch [   77/  100] | d_loss: 1.1099 | g_loss: 1.0331
# Epoch [   78/  100] | d_loss: 1.2276 | g_loss: 1.3160
# Epoch [   78/  100] | d_loss: 1.2628 | g_loss: 1.0224
# Epoch [   78/  100] | d_loss: 1.2703 | g_loss: 1.0824
# Epoch [   79/  100] | d_loss: 1.3747 | g_loss: 1.1720
# Epoch [   79/  100] | d_loss: 1.1684 | g_loss: 1.1823
# Epoch [   79/  100] | d_loss: 1.3556 | g_loss: 0.9406
# Epoch [   80/  100] | d_loss: 1.2174 | g_loss: 1.1441
# Epoch [   80/  100] | d_loss: 1.3556 | g_loss: 0.9980
# Epoch [   80/  100] | d_loss: 1.3212 | g_loss: 0.9362
# Epoch [   81/  100] | d_loss: 1.2832 | g_loss: 1.0771
# Epoch [   81/  100] | d_loss: 1.2994 | g_loss: 1.0427
# Epoch [   81/  100] | d_loss: 1.2644 | g_loss: 1.1971
# Epoch [   82/  100] | d_loss: 1.2530 | g_loss: 1.3750
# Epoch [   82/  100] | d_loss: 1.3074 | g_loss: 1.0681
# Epoch [   82/  100] | d_loss: 1.2585 | g_loss: 0.9683
# Epoch [   83/  100] | d_loss: 1.2865 | g_loss: 1.0316
# Epoch [   83/  100] | d_loss: 1.2782 | g_loss: 1.0228
# Epoch [   83/  100] | d_loss: 1.2809 | g_loss: 0.9416
# Epoch [   84/  100] | d_loss: 1.1742 | g_loss: 1.0466
# Epoch [   84/  100] | d_loss: 1.3354 | g_loss: 0.9331
# Epoch [   84/  100] | d_loss: 1.2923 | g_loss: 1.1289
# Epoch [   85/  100] | d_loss: 1.2565 | g_loss: 1.1534
# Epoch [   85/  100] | d_loss: 1.2583 | g_loss: 0.9716
# Epoch [   85/  100] | d_loss: 1.3304 | g_loss: 0.9931
# Epoch [   86/  100] | d_loss: 1.2872 | g_loss: 1.2174
# Epoch [   86/  100] | d_loss: 1.3374 | g_loss: 1.0565
# Epoch [   86/  100] | d_loss: 1.1684 | g_loss: 1.0227
# Epoch [   87/  100] | d_loss: 1.2766 | g_loss: 1.1002
# Epoch [   87/  100] | d_loss: 1.2522 | g_loss: 1.0543
# Epoch [   87/  100] | d_loss: 1.2766 | g_loss: 1.0645
# Epoch [   88/  100] | d_loss: 1.3133 | g_loss: 1.0242
# Epoch [   88/  100] | d_loss: 1.2216 | g_loss: 1.2223
# Epoch [   88/  100] | d_loss: 1.1903 | g_loss: 1.1849
# Epoch [   89/  100] | d_loss: 1.2311 | g_loss: 1.0794
# Epoch [   89/  100] | d_loss: 1.2416 | g_loss: 0.9469
# Epoch [   89/  100] | d_loss: 1.3131 | g_loss: 1.0015
# Epoch [   90/  100] | d_loss: 1.1670 | g_loss: 1.1058
# Epoch [   90/  100] | d_loss: 1.2162 | g_loss: 0.9993
# Epoch [   90/  100] | d_loss: 1.3822 | g_loss: 1.1093
# Epoch [   91/  100] | d_loss: 1.2458 | g_loss: 1.0830
# Epoch [   91/  100] | d_loss: 1.3856 | g_loss: 1.0214
# Epoch [   91/  100] | d_loss: 1.2752 | g_loss: 1.0050
# Epoch [   92/  100] | d_loss: 1.3051 | g_loss: 0.9529
# Epoch [   92/  100] | d_loss: 1.1879 | g_loss: 0.9363
# Epoch [   92/  100] | d_loss: 1.2628 | g_loss: 0.8617
# Epoch [   93/  100] | d_loss: 1.2756 | g_loss: 1.0529
# Epoch [   93/  100] | d_loss: 1.3251 | g_loss: 1.0003
# Epoch [   93/  100] | d_loss: 1.3016 | g_loss: 0.9282
# Epoch [   94/  100] | d_loss: 1.2863 | g_loss: 1.0259
# Epoch [   94/  100] | d_loss: 1.2591 | g_loss: 1.0120
# Epoch [   94/  100] | d_loss: 1.3083 | g_loss: 1.0854
# Epoch [   95/  100] | d_loss: 1.3575 | g_loss: 1.1354
# Epoch [   95/  100] | d_loss: 1.2759 | g_loss: 1.0739
# Epoch [   95/  100] | d_loss: 1.2456 | g_loss: 1.0438
# Epoch [   96/  100] | d_loss: 1.1824 | g_loss: 1.1293
# Epoch [   96/  100] | d_loss: 1.2047 | g_loss: 0.9862
# Epoch [   96/  100] | d_loss: 1.4154 | g_loss: 0.9971
# Epoch [   97/  100] | d_loss: 1.1730 | g_loss: 1.1204
# Epoch [   97/  100] | d_loss: 1.4464 | g_loss: 0.8890
# Epoch [   97/  100] | d_loss: 1.3042 | g_loss: 0.9967
# Epoch [   98/  100] | d_loss: 1.1975 | g_loss: 1.1421
# Epoch [   98/  100] | d_loss: 1.2618 | g_loss: 1.0448
# Epoch [   98/  100] | d_loss: 1.2724 | g_loss: 1.0117
# Epoch [   99/  100] | d_loss: 1.2974 | g_loss: 1.0680
# Epoch [   99/  100] | d_loss: 1.3855 | g_loss: 1.2238
# Epoch [   99/  100] | d_loss: 1.1540 | g_loss: 0.9923
# Epoch [  100/  100] | d_loss: 1.2236 | g_loss: 1.1764
# Epoch [  100/  100] | d_loss: 1.2811 | g_loss: 0.9736
# Epoch [  100/  100] | d_loss: 1.1513 | g_loss: 0.9907

# %%
fig, ax = plt.subplots()
losses = np.array(losses)
plt.plot(losses.T[0], label='Discriminator')
plt.plot(losses.T[1], label='Generator')
plt.title("Training Losses")
plt.legend()

# %%
# helper function for viewing a list of passed in sample images
def view_samples(epoch, samples):
    fig, axes = plt.subplots(figsize=(7,7), nrows=4, ncols=4, sharey=True, sharex=True)
    for ax, img in zip(axes.flatten(), samples[epoch]):
        img = img.detach()
        ax.xaxis.set_visible(False)
        ax.yaxis.set_visible(False)
        im = ax.imshow(img.reshape((28,28)), cmap='Greys_r')

# %%
# Load samples from generator, taken while training
with open('train_samples.pkl', 'rb') as f:
    samples = pkl.load(f)

# %%
# -1 indicates final epoch's samples (the last in the list)
view_samples(-1, samples)

# %%
rows = 10 # split epochs into 10, so 100/10 = every 10 epochs
cols = 6
fig, axes = plt.subplots(figsize=(7,12), nrows=rows, ncols=cols, sharex=True, sharey=True)

for sample, ax_row in zip(samples[::int(len(samples)/rows)], axes):
    for img, ax in zip(sample[::int(len(sample)/cols)], ax_row):
        img = img.detach()
        ax.imshow(img.reshape((28,28)), cmap='Greys_r')
        ax.xaxis.set_visible(False)
        ax.yaxis.set_visible(False)

# %%
# randomly generated, new latent vectors
sample_size=16
rand_z = np.random.uniform(-1, 1, size=(sample_size, z_size))
rand_z = torch.from_numpy(rand_z).float()

G.eval() # eval mode
# generated samples
rand_images = G(rand_z)

# 0 indicates the first set of samples in the passed in list
# and we only have one batch of samples, here
view_samples(0, [rand_images])
